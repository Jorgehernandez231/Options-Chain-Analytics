# %%
import requests, json
url = "https://cdn.cboe.com/api/global/delayed_quotes/options/_SPX.json"
data = requests.get(url).json()

print("\nTOP-LEVEL KEYS:", list(data.keys()))

print("\nDATA TYPE:", type(data.get("data")))
print("DATA KEYS:", list(data.get("data", {}).keys()))
# Out:
# TOP-LEVEL KEYS: ['timestamp', 'data', 'symbol']
#
# DATA TYPE: <class 'dict'>
# DATA KEYS: ['options', 'symbol', 'security_type', 'exchange_id', 'current_price', 'price_change', 'price_change_percent', 'bid', 'ask', 'bid_size', 'ask_size', 'open', 'high', 'low', 'close', 'prev_day_close', 'volume', 'iv30', 'iv30_change', 'iv30_change_percent', 'seqno', 'last_trade_time', 'tick']

# %%
import pandas as pd

df = pd.read_csv('data/spx_quotedata.csv', skiprows=3)
df
# Out:
#        Expiration Date                Calls  Last Sale  Net     Bid     Ask  \
# 0      Thu Nov 06 2025  SPXW251106C02800000    3999.00  0.0  3923.2  3941.1
# 1      Thu Nov 06 2025  SPXW251106C03000000       0.00  0.0  3723.7  3740.6
# 2      Thu Nov 06 2025  SPXW251106C03200000       0.00  0.0  3523.8  3540.6
# 3      Thu Nov 06 2025  SPXW251106C03400000       0.00  0.0  3323.8  3340.6
# 4      Thu Nov 06 2025  SPXW251106C03600000       0.00  0.0  3123.8  3138.8
# ...                ...                  ...        ...  ...     ...     ...
# 13374  Fri Dec 20 2030   SPX301220C10800000     205.00  0.0   213.0   247.0
# 13375  Fri Dec 20 2030   SPX301220C11000000     226.72  0.0   184.9   217.8
# 13376  Fri Dec 20 2030   SPX301220C11200000     207.65  0.0   160.2   192.0
# 13377  Fri Dec 20 2030   SPX301220C11400000     123.64  0.0   138.5   169.3
# 13378  Fri Dec 20 2030   SPX301220C12000000     116.90  0.0   100.0   114.2
#
#        Volume      IV   Delta   Gamma  ...                 Puts  Last Sale.1  \
# 0           0  0.0000  1.0000  0.0000  ...  SPXW251106P02800000         0.05
# 1           0  0.0000  1.0000  0.0000  ...  SPXW251106P03000000         0.05
# 2           0  0.0000  1.0000  0.0000  ...  SPXW251106P03200000         0.10
# 3           0  0.0000  1.0000  0.0000  ...  SPXW251106P03400000         0.25
# 4           0  0.0000  1.0000  0.0000  ...  SPXW251106P03600000         0.05
# ...       ...     ...     ...     ...  ...                  ...          ...
# 13374       0  0.1441  0.2287  0.0001  ...   SPX301220P10800000         0.00
# 13375       0  0.1423  0.2067  0.0001  ...   SPX301220P11000000      2567.53
# 13376       0  0.1407  0.1866  0.0001  ...   SPX301220P11200000      2724.51
# 13377       0  0.1393  0.1689  0.0001  ...   SPX301220P11400000      2857.97
# 13378       0  0.1375  0.1304  0.0001  ...   SPX301220P12000000      3309.11
#
#        Net.1   Bid.1    Ask.1  Volume.1    IV.1  Delta.1  Gamma.1  \
# 0      0.025     0.0     0.05        10  0.0000   0.0000   0.0000
# 1      0.025     0.0     0.05         1  0.0000   0.0000   0.0000
# 2      0.000     0.0     0.05         0  0.0000   0.0000   0.0000
# 3      0.000     0.0     0.05         0  0.0000   0.0000   0.0000
# 4      0.000     0.0     0.05         0  0.0000   0.0000   0.0000
# ...      ...     ...      ...       ...     ...      ...      ...
# 13374  0.000  2386.1  2686.10         0  0.1451  -0.8053   0.0001
# 13375  0.000  2520.8  2820.80         0  0.1386  -0.8273   0.0001
# 13376  0.000  2687.3  2987.30         0  0.1417  -0.8474   0.0001
# 13377  0.000  2828.4  3128.40         0  0.1359  -0.8651   0.0001
# 13378  0.000  3242.1  3542.10         0  0.1375  -0.9036   0.0001
#
#        Open Interest.1
# 0                    0
# 1                   40
# 2                   36
# 3                    1
# 4                    2
# ...                ...
# 13374                0
# 13375                2
# 13376                1
# 13377                1
# 13378                4
#
# [13379 rows x 22 columns]
